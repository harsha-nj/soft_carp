# %%
def far_cel(F):
    # c=(F-32) x (5/9)
    celsius=(F-32) * (5/9)
    return celsius

# %%
far_cel(F=35)
# Out:
# 1.6666666666666667

# %%
fahr=far_cel(F=276)

# %%
fahr
# Out:
# 135.55555555555557

# %%
import pandas as pd

# %%
dem_health_data=pd.read_csv("Dem_Health_Full.txt",sep='\t')

# %%
dem_health_data.head()
# Out:
#     County State  Population_Density  Poverty  Infant_Mortality  Suicide  \
# 0  Autauga    AL                  82     10.4               5.9     16.6
# 1  Baldwin    AL                 102     10.2               7.1     14.3
# 2  Barbour    AL                  32     22.1               7.1     10.3
# 3     Bibb    AL                  35     16.8               9.8     14.8
# 4   Blount    AL                  86     11.9               9.0     14.4
#
#    Total_Births  Total_Deaths
# 0        3048.0        1867.0
# 1        5471.0        4388.0
# 2        1835.0        1538.0
# 3        2801.0        2012.0
# 4        3318.0        2453.0

# %%
dem_health_data.head(20)
# Out:
#        County State  Population_Density  Poverty  Infant_Mortality  Suicide  \
# 0     Autauga    AL                  82     10.4               5.9     16.6
# 1     Baldwin    AL                 102     10.2               7.1     14.3
# 2     Barbour    AL                  32     22.1               7.1     10.3
# 3        Bibb    AL                  35     16.8               9.8     14.8
# 4      Blount    AL                  86     11.9               9.0     14.4
# 5     Bullock    AL                  18     26.2              13.3  -1111.1
# 6      Butler    AL                  27     20.0               5.8     11.9
# 7     Calhoun    AL                 184     16.4               9.5     13.6
# 8    Chambers    AL                  59     16.2               7.5     12.8
# 9    Cherokee    AL                  44     15.2               7.4     17.7
# 10    Chilton    AL                  60     14.9              10.5     13.3
# ...

# %%
def get_urban(df):
    urban=pd.loc[df['Population_Density']>=1000,:]
    return urban

# %%
urban_counties= get_urban(dem_health_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-cee507dbe210> in <module>()
# ----> 1 urban_counties= get_urban(dem_health_data)
#
# <ipython-input-9-5a74f455f05a> in get_urban(df)
#       1 def get_urban(df):
# ----> 2     urban=pd.loc[df['Poplution_Density']>=1000,:]
#       3     return urban
#
# AttributeError: module 'pandas' has no attribute 'loc'

# %%
def get_urban(df):
    urban=df.loc[df['Poplation_Density']>=1000,:]
    return urban

# %%
urban_counties= get_urban(dem_health_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\njish\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: 'Poplution_Density'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
def get_urban(df):
    urban=df.loc[df['Population_Density']>=1000,:]
    return urban

# %%
urban_counties= get_urban(dem_health_data)

# %%
urban_counties
# Out:
#                      County State  Population_Density  Poverty  \
# 184                 Alameda    CA                1964     10.7
# 190            Contra Costa    CA                1414      7.5
# 202             Los Angeles    CA                2447     17.7
# 213                  Orange    CA                3785     10.6
# 217              Sacramento    CA                1412     13.7
# 221           San Francisco    CA               15837     12.0
# 224               San Mateo    CA                1558      6.8
# 226             Santa Clara    CA                1316      8.8
# 258                  Denver    CO                3638     15.1
# 306               Fairfield    CT                1443      7.3
# 307                Hartford    CT                1193      9.2
# 310               New Haven    CT                1398      9.4
# 315              New Castle    DE                1227      8.2
# 317              Washington    DC                8966     17.5
# ...

# %%
def get_urban(df, threshold):
    urban=df.loc[df['Population_Density']>=threshold,:]
    return urban

# %%
urban_counties= get_urban(dem_health_data, 10000)

# %%
urban_counties
# Out:
#              County State  Population_Density  Poverty  Infant_Mortality  \
# 221   San Francisco    CA               15837     12.0               3.9
# 1227        Suffolk    MA               11183     15.9               6.1
# 1780         Hudson    NJ               12926     15.0               7.4
# 1828          Bronx    NY               32300     26.8               6.8
# 1849          Kings    NY               35211     23.3               6.5
# 1856       New York    NY               69390     18.6               4.9
# 1866         Queens    NY               20520     15.4               5.2
# 2292   Philadelphia    PA               10832     20.1              10.4
#
#       Suicide  Total_Births  Total_Deaths
# 221      11.0       25255.0       18969.0
# 1227      5.7       28649.0       16317.0
# 1780      4.8       26507.0       13726.0
# 1828      5.8       68201.0       30886.0
# 1849      4.6      119171.0       54937.0
# 1856      8.2       60627.0       34423.0
# ...

# %%
def split_county_by_pop(df,threshold):
    urban=df.loc[df['Population Density'] >=threshold,:]
    rural=df.loc[df['Population Density'] <threshold,:]
    return [urban, rural]

# %%
urban_rural_counties=split_county_by_pop(dem_health_data, 1000)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\njish\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: 'Population Density'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
def split_county_by_pop(df,threshold):
    urban=df.loc[df['Population_Density'] >=threshold,:]
    rural=df.loc[df['Population_Density'] <threshold,:]
    return [urban, rural]

# %%
urban_rural_counties=split_county_by_pop(dem_health_data, 1000)

# %%
urban_rural_counties[1]
# Out:
#            County State  Population_Density  Poverty  Infant_Mortality  \
# 0         Autauga    AL                  82     10.4               5.9
# 1         Baldwin    AL                 102     10.2               7.1
# 2         Barbour    AL                  32     22.1               7.1
# 3            Bibb    AL                  35     16.8               9.8
# 4          Blount    AL                  86     11.9               9.0
# 5         Bullock    AL                  18     26.2              13.3
# 6          Butler    AL                  27     20.0               5.8
# 7         Calhoun    AL                 184     16.4               9.5
# 8        Chambers    AL                  59     16.2               7.5
# 9        Cherokee    AL                  44     15.2               7.4
# 10        Chilton    AL                  60     14.9              10.5
# 11        Choctaw    AL                  16     18.7              10.8
# ...

# %%
urban_rural_counties[0]
# Out:
#                      County State  Population_Density  Poverty  \
# 184                 Alameda    CA                1964     10.7
# 190            Contra Costa    CA                1414      7.5
# 202             Los Angeles    CA                2447     17.7
# 213                  Orange    CA                3785     10.6
# 217              Sacramento    CA                1412     13.7
# 221           San Francisco    CA               15837     12.0
# 224               San Mateo    CA                1558      6.8
# 226             Santa Clara    CA                1316      8.8
# 258                  Denver    CO                3638     15.1
# 306               Fairfield    CT                1443      7.3
# 307                Hartford    CT                1193      9.2
# 310               New Haven    CT                1398      9.4
# 315              New Castle    DE                1227      8.2
# 317              Washington    DC                8966     17.5
# ...

# %%
urban_rural_counties[0:1]
# Out:
# [                     County State  Population_Density  Poverty  \
#  184                 Alameda    CA                1964     10.7
#  190            Contra Costa    CA                1414      7.5
#  202             Los Angeles    CA                2447     17.7
#  213                  Orange    CA                3785     10.6
#  217              Sacramento    CA                1412     13.7
#  221           San Francisco    CA               15837     12.0
#  224               San Mateo    CA                1558      6.8
#  226             Santa Clara    CA                1316      8.8
#  258                  Denver    CO                3638     15.1
#  306               Fairfield    CT                1443      7.3
#  307                Hartford    CT                1193      9.2
#  310               New Haven    CT                1398      9.4
#  315              New Castle    DE                1227      8.2
#  317              Washington    DC                8966     17.5
# ...

# %%
len(urban_rural_counties)
# Out:
# 2

# %%
len(urban_rural_counties[0])
# Out:
# 137

# %%
len(urban_rural_counties[1])
# Out:
# 3004

# %%
urban_rural_counties[0,1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-317e337d7ed1> in <module>()
# ----> 1 urban_rural_counties[0,1]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
urban_rural_counties[0:0,1:1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-76f8e2dc97bd> in <module>()
# ----> 1 urban_rural_counties[0:0,1:1]
#
# TypeError: list indices must be integers or slices, not tuple
